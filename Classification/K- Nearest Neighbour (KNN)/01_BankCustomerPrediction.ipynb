# %% [markdown]
# ## The data given in the url  is related with direct marketing campaigns of a banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed. Build a model to predict whether client will subscribe to term deposit

# %% [raw]
# https://drive.google.com/open?id=1E0EURgsF3L9Bt5hnOalE0d4Tw9mIOgTn

# %% [markdown]
# ### Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/home/admin1/PycharmProjects/Models in Machine Learning/')
from ipynb.fs.full.ml_library import *

# reading dataset from csv file & storing pandas dataframe
bank_data = pd.read_csv('bank.csv', sep=';')
bank_data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank_data.isna().sum()       # checking null values
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# mapping target variable i.e. column 'y' to 0 & 1
# mapping  'no' -> 0  &  'yes' -> 1
bank_data.loc[bank_data['y'] == 'no', 'y'] = 0
bank_data.loc[bank_data['y'] == 'yes', 'y']= 1
bank_data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   19   oct        79         1     -1         0  unknown  0
# 1  cellular   11   may       220         1    339         4  failure  0
# 2  cellular   16   apr       185         1    330         1  failure  0
# 3   unknown    3   jun       199         4     -1         0  unknown  0
# 4   unknown    5   may       226         1     -1         0  unknown  0

# %% [markdown]
# #### Checking all features have contributed to target variable or not

# %%
# checking numeric columns variation with target variable
bank_data.groupby('y').mean()
# Out:
#          age      balance        day    duration  campaign      pdays  \
# y
# 0  40.998000  1403.211750  15.948750  226.347500  2.862250  36.006000
# 1  42.491363  1571.955854  15.658349  552.742802  2.266795  68.639155
#
#    previous
# y
# 0  0.471250
# 1  1.090211

# %%
bank_data.groupby('marital').mean()
# Out:
#                 age      balance        day    duration  campaign      pdays  \
# marital
# divorced  45.475379  1122.390152  15.753788  279.232955  2.604167  38.827652
# married   43.454415  1463.195567  15.905971  256.528781  2.847336  38.466929
# single    33.927258  1460.414716  16.008361  274.601171  2.751672  43.220736
#
#           previous         y
# marital
# divorced  0.439394  0.145833
# married   0.519128  0.099035
# single    0.642977  0.139632

# %%
bank_data.groupby('education').mean()
# Out:
#                  age      balance        day    duration  campaign      pdays  \
# education
# primary    46.833333  1411.544248  15.505900  261.709440  2.865782  35.069322
# secondary  40.062446  1196.814397  15.977884  269.863833  2.734172  40.934085
# tertiary   39.645926  1775.423704  16.009630  256.881481  2.901481  39.824444
# unknown    45.299465  1701.245989  15.946524  250.449198  2.486631  41.983957
#
#            previous         y
# education
# primary    0.460177  0.094395
# secondary  0.528621  0.106245
# tertiary   0.612593  0.142963
# unknown    0.508021  0.101604

# %%
bank_data.groupby('job').mean()
# Out:
#                      age      balance        day    duration  campaign  \
# job
# admin.         39.682008  1226.736402  16.324268  234.669456  2.631799
# blue-collar    40.156448  1085.161734  15.482030  278.161734  2.846723
# entrepreneur   42.011905  1645.125000  15.255952  285.476190  2.589286
# housemaid      47.339286  2083.803571  15.294643  292.633929  2.500000
# management     40.540764  1766.928793  16.254902  260.536636  2.973168
# retired        61.869565  2319.191304  15.556522  285.656522  2.465217
# self-employed  41.453552  1392.409836  16.180328  264.125683  3.278689
# services       38.570743  1103.956835  15.515588  262.486811  2.822542
# student        26.821429  1543.821429  16.392857  248.690476  2.392857
# technician     39.470052  1330.996094  16.183594  252.178385  2.731771
# unemployed     40.906250  1089.421875  16.093750  301.265625  2.679688
# unknown        48.105263  1501.710526  15.842105  216.921053  2.552632
#
#                    pdays  previous         y
# job
# admin.         49.993724  0.644351  0.121339
# blue-collar    41.590909  0.493658  0.072939
# entrepreneur   32.273810  0.428571  0.089286
# housemaid      26.401786  0.357143  0.125000
# management     40.968008  0.549020  0.135191
# retired        35.073913  0.591304  0.234783
# self-employed  28.256831  0.590164  0.109290
# services       36.371703  0.443645  0.091127
# student        45.714286  0.964286  0.226190
# technician     39.265625  0.576823  0.108073
# unemployed     36.625000  0.484375  0.101562
# unknown        36.236842  0.500000  0.184211

# %%
bank_data.groupby('poutcome').mean()
# Out:
#                 age      balance        day    duration  campaign       pdays  \
# poutcome
# failure   41.555102  1644.646939  14.395918  254.383673  1.955102  243.167347
# other     39.873096  1424.472081  15.101523  273.832487  2.350254  219.385787
# success   44.170543  1949.410853  14.581395  338.635659  1.736434  163.713178
# unknown   41.083671  1374.862078  16.205938  262.103104  2.964912   -1.000000
#
#           previous         y
# poutcome
# failure   2.851020  0.128571
# other     3.385787  0.192893
# success   3.015504  0.643411
# unknown   0.000000  0.090958

# %%
bank_data.groupby('housing').mean()
# Out:
#                age      balance        day    duration  campaign      pdays  \
# housing
# no       43.511723  1595.277268  16.209990  259.290520   2.80632  26.402141
# yes      39.374756  1290.309496  15.689332  267.542399   2.78390  50.013286
#
#          previous         y
# housing
# no       0.467890  0.153415
# yes      0.599844  0.085971

# %%
bank_data.groupby('loan').mean()
# Out:
#             age      balance        day    duration  campaign      pdays  \
# loan
# no    41.220627  1513.857963  15.932376  264.512794  2.771018  41.088512
# yes   40.890014   917.163531  15.820550  260.904486  2.918958  32.439942
#
#       previous         y
# loan
# no    0.558486  0.124804
# yes   0.454414  0.062229

# %%
bank_data.groupby('default').mean()
# Out:
#                age      balance        day    duration  campaign      pdays  \
# default
# no       41.194826  1450.550956  15.929584  264.355906   2.79865  40.111136
# yes      39.723684  -208.723684  15.078947  240.881579   2.50000  19.618421
#
#          previous         y
# default
# no       0.548481  0.115186
# yes      0.197368  0.118421

# %%
bank_data.drop(['default', 'balance', 'contact', 'day', 'month'], axis=1, inplace=True)
bank_data.head()
# Out:
#    age          job  marital  education housing loan  duration  campaign  \
# 0   30   unemployed  married    primary      no   no        79         1
# 1   33     services  married  secondary     yes  yes       220         1
# 2   35   management   single   tertiary     yes   no       185         1
# 3   30   management  married   tertiary     yes  yes       199         4
# 4   59  blue-collar  married  secondary     yes   no       226         1
#
#    pdays  previous poutcome  y
# 0     -1         0  unknown  0
# 1    339         4  failure  0
# 2    330         1  failure  0
# 3     -1         0  unknown  0
# 4     -1         0  unknown  0

# %% [markdown]
# #### Handling categorical data

# %%
# converted categorical data into number-wise category
# if only 2 categories then 0 & 1  i.e.  (no / yes)
# else numbers 1,2,3,...(No of categories)

# finding categorical columns
categorical_col = [col for col in bank_data.columns if bank_data[col].dtype == 'O']

for col in categorical_col:
    # sorting ccatories of the column
    categories = sorted(bank_data[col].unique())
    if len(categories) == 2:
        code = 0
        for category in categories:
            bank_data.loc[bank_data[col] == category, col] = code
            code += 1
    else:
        code = 1
        for category in categories:
            bank_data.loc[bank_data[col] == category, col] = code
            code += 1
bank_data.head()
# Out:
#    age  job  marital  education  housing  loan  duration  campaign  pdays  \
# 0   30   11        2          1        0     0        79         1     -1
# 1   33    8        2          2        1     1       220         1    339
# 2   35    5        3          3        1     0       185         1    330
# 3   30    5        2          3        1     1       199         4     -1
# 4   59    2        2          2        1     0       226         1     -1
#
#    previous  poutcome  y
# 0         0         4  0
# 1         4         1  0
# 2         1         1  0
# 3         0         4  0
# 4         0         4  0

# %%
# scaling columns age, duration, pdays in range 0-1
for col in bank_data.columns:
    minimum = bank_data[col].min()
    maximum = bank_data[col].max()
    bank_data[col] = (bank_data[col] - minimum)/(maximum - minimum)

bank_data.head()
# Out:
#         age       job  marital  education  housing  loan  duration  campaign  \
# 0  0.161765  0.909091      0.5   0.000000      0.0   0.0  0.024826  0.000000
# 1  0.205882  0.636364      0.5   0.333333      1.0   1.0  0.071500  0.000000
# 2  0.235294  0.363636      1.0   0.666667      1.0   0.0  0.059914  0.000000
# 3  0.161765  0.363636      0.5   0.666667      1.0   1.0  0.064548  0.061224
# 4  0.588235  0.090909      0.5   0.333333      1.0   0.0  0.073486  0.000000
#
#       pdays  previous  poutcome    y
# 0  0.000000      0.00       1.0  0.0
# 1  0.389908      0.16       0.0  0.0
# 2  0.379587      0.04       0.0  0.0
# 3  0.000000      0.00       1.0  0.0
# 4  0.000000      0.00       1.0  0.0

# %% [markdown]
# #### Removing one of the correlated columns

# %%
bank_data = bank_data.drop('pdays', axis=1)

# %%
bank_data.describe()
# Out:
#                age          job      marital    education      housing  \
# count  4521.000000  4521.000000  4521.000000  4521.000000  4521.000000
# mean      0.326031     0.401017     0.573877     0.410455     0.566025
# std       0.155533     0.295974     0.299825     0.249581     0.495676
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.205882     0.090909     0.500000     0.333333     0.000000
# 50%       0.294118     0.363636     0.500000     0.333333     1.000000
# 75%       0.441176     0.636364     1.000000     0.666667     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               loan     duration     campaign     previous     poutcome  \
# count  4521.000000  4521.000000  4521.000000  4521.000000  4521.000000
# mean      0.152842     0.086051     0.036605     0.021703     0.853056
# std       0.359875     0.086017     0.063465     0.067742     0.330684
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.033102     0.000000     0.000000     1.000000
# 50%       0.000000     0.059914     0.020408     0.000000     1.000000
# 75%       0.000000     0.107580     0.040816     0.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  y
# count  4521.000000
# mean      0.115240
# std       0.319347
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# #### Splitting dataset into train & test set

# %%
# Splitting 70 % dataset into train set & 30 % dataset into dataset into test set
train = bank_data.sample(frac=0.7, random_state=3)   # selecting random 0.7 fraction of dataset as train set   
# chossing different random state will give different random rows
test = bank_data.drop(train.index)            # selecting remaining i.e. 30% as test set
print('Train set')
print(train.shape)
train.head()
# Out:
# Train set
# (3165, 11)
#            age       job  marital  education  housing  loan  duration  \
# 3542  0.250000  0.636364      0.5   0.333333      1.0   0.0  0.031447
# 2687  0.382353  0.818182      0.5   0.333333      0.0   0.0  0.023833
# 2053  0.073529  0.818182      1.0   0.333333      1.0   0.0  0.006289
# 3966  0.323529  0.818182      0.0   0.333333      0.0   0.0  0.085071
# 1602  0.411765  0.000000      0.0   0.333333      1.0   0.0  0.065872
#
#       campaign  previous  poutcome    y
# 3542  0.000000       0.0       1.0  0.0
# 2687  0.000000       0.0       1.0  0.0
# 2053  0.000000       0.0       1.0  0.0
# 3966  0.020408       0.0       1.0  0.0
# 1602  0.061224       0.0       1.0  0.0

# %%
print('Test set')
print(test.shape)
test.head()
# Out:
# Test set
# (1356, 11)
#          age       job  marital  education  housing  loan  duration  campaign  \
# 1   0.205882  0.636364      0.5   0.333333      1.0   1.0  0.071500  0.000000
# 7   0.294118  0.818182      0.5   0.333333      1.0   0.0  0.048659  0.020408
# 8   0.323529  0.181818      0.5   0.666667      1.0   0.0  0.017544  0.020408
# 13  0.014706  0.727273      1.0   0.333333      0.0   0.0  0.085071  0.000000
# 14  0.176471  0.090909      0.5   0.333333      1.0   1.0  0.028136  0.000000
#
#     previous  poutcome    y
# 1       0.16       0.0  0.0
# 7       0.00       1.0  0.0
# 8       0.00       1.0  0.0
# 13      0.00       1.0  1.0
# 14      0.04       0.0  0.0

# %% [markdown]
# #### Creating predictors & target variables in both data set

# %%
def create_pred_target(data):   
    """Function returns predictors' matrix & target variable's array for given dataset"""
    y_values = np.array(data['y'])
    x_values = np.array(data[data.columns[0]]).reshape(len(data),1)
    
    for col in data.columns[1:]:
        if col != 'y':
            new_col = np.array(data[col]).reshape(len(data), 1)
            x_values = np.append(x_values, new_col, axis=1)

    return x_values, y_values

train_x_values, train_y_values = create_pred_target(train)
test_x_values, test_y_values = create_pred_target(test)

# %% [markdown]
# ### Building KNN model

# %%
k_number = 10       # total number of neighbours we have chosen 

# finding euclidean distance single test record & all train records
euclidean_distances = lambda x_val: np.sqrt(((x_val - train_x_values)**2).sum(axis=1))
        
# predicting label for single record of dataset   
def predict_single(x_val):
    distances = euclidean_distances(x_val)
    distance_target_data = pd.DataFrame({'Distances':distances, 'Target':train_y_values})
    k_nearest_neighbours =  distance_target_data.sort_values('Distances')[:k_number]
    return k_nearest_neighbours['Target'].sum() > (k_number/2)

# predicting for total records for given dataset
def predict(x_values):
    return np.array(list(map(predict_single, x_values)))

# %% [markdown]
# #### Storing predictions for test set

# %%
train_predicted_values = predict(train_x_values)
test_predicted_values = predict(test_x_values)

# %%
# categorise each record to it's category
train_predicted_values = categorise_knn(train_predicted_values)
test_predicted_values = categorise_knn(test_predicted_values)

# %% [markdown]
# ### Evaluating accuracy against test set

# %%
accuracy_train_set = accuracy_classification(train_predicted_values, train_y_values)
accuracy_train_set
# Out:
# 89.478672985782

# %%
accuracy_test_set = accuracy_classification(test_predicted_values, test_y_values)
accuracy_test_set
# Out:
# 88.49557522123894
